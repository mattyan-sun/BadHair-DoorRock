# %%
import glob

# %%
import numpy as np

# %%
from keras.preprocessing.image import load_img, img_to_array, array_to_img
from keras.preprocessing.image import random_rotation, random_shift, random_zoom
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dense
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.models import Sequential
from keras.models import model_from_json
from keras.callbacks import LearningRateScheduler
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils

# %%
DirNames = ["./dataset/bad_hair", "./dataset/good_hair"] 
FileNames = ["./dataset/bad_hair.npy", "./dataset/good_hair.npy"]
ClassNames = ["bad_hair", "good_hair"]
hw = {"height":16, "width":16}        #画像サイズ　リストではなく辞書型 中かっこで囲む

# %%
def PreProcess(dirname, filename, var_amount=100): #var_amount:一枚の画像から得られるサンプル数
    #定義
    num = 0
    arrlist = []
    #ファイルの読み込み
    files = glob.glob(dirname + "/*.jpg")
    #画像処理
    for imgfile in files:
        img = load_img(imgfile, target_size=(hw["height"], hw["width"]))    # 画像ファイルの読み込み
        array = img_to_array(img) / 255                                     # 画像ファイルのnumpy化
        arrlist.append(array)                 # numpy型データをリストに追加
        for i in range(var_amount-1): # 1枚あたり2枚の回転画像が得られる
            arr2 = array
            arr2 = random_rotation(arr2, rg=360)
            arrlist.append(arr2)              # numpy型データをリストに追加
        num += 1
    nplist = np.array(arrlist)
    np.save(filename, nplist)
    print(">> " + dirname + "から" + str(num) + "個のファイル読み込み成功")

# %%
PreProcess(DirNames[0], DirNames[0])
PreProcess(DirNames[1], DirNames[1])
print(np.load("./dataset/bad_hair.npy").shape)
# Out:
# >> ./dataset/bad_hairから1個のファイル読み込み成功
# >> ./dataset/good_hairから1個のファイル読み込み成功
# (100, 16, 16, 3)

# %%
def BuildCNN(ipshape=(32, 32, 3), num_classes=2):
    model = Sequential()
  
     #層1
    model.add(Conv2D(24, 3, padding='same', input_shape=ipshape))
    model.add(Activation('relu'))
  
    #層2
    model.add(Conv2D(48, 3))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.5))
  
    #層3,4
    model.add(Conv2D(96, 3, padding='same'))
    model.add(Activation('relu'))

    model.add(Conv2D(96, 3))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.5))

    #層5
    model.add(Flatten())
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    #層6
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))
  
    #構築
    adam = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
    model.compile(loss='categorical_crossentropy',
                  optimizer=adam,
                  metrics=['accuracy'])
    return model

# %%
def Learning(tsnum=30, nb_epoch=50, batch_size=8, learn_schedule=0.9):
    X_TRAIN_list = []; Y_TRAIN_list = []; X_TEST_list = []; Y_TEST_list = [];
    target = 0
    for filename in FileNames :
        data = np.load(filename)          # 画像のnumpyデータを読み込み
        trnum = data.shape[0] - tsnum
        X_TRAIN_list += [data[i] for i in range(trnum)]          # 画像データ
        Y_TRAIN_list += [target] * trnum                         # 分類番号
        X_TEST_list  += [data[i] for i in range(trnum, trnum+tsnum)]          # 学習しない画像データ
        Y_TEST_list  += [target] * tsnum;                                     # 学習しない分類番号
        target += 1
    X_TRAIN = np.array(X_TRAIN_list + X_TEST_list)    # 連結
    Y_TRAIN = np.array(Y_TRAIN_list + Y_TEST_list)    # 連結
    print(">> 学習サンプル数 : ", X_TRAIN.shape)
    y_train = np_utils.to_categorical(Y_TRAIN, target)    # 自然数をベクトルに変換
    valrate = tsnum * target * 1.0 / X_TRAIN.shape[0]

    # 学習率の変更
    class Schedule(object):
        def __init__(self, init=0.001):      # 初期値定義
            self.init = init
        def __call__(self, epoch):           # 現在値計算
            lr = self.init
            for i in range(1, epoch+1):
                lr *= learn_schedule
            return lr
  
    def get_schedule_func(init):
        return Schedule(init)

    lrs = LearningRateScheduler(get_schedule_func(0.001))
    mcp = ModelCheckpoint(filepath='./keras/best.hdf5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
    model = BuildCNN(ipshape=(X_TRAIN.shape[1], X_TRAIN.shape[2], X_TRAIN.shape[3]), num_classes=target)

    print(">> 学習開始")
    hist = model.fit(X_TRAIN, y_train,
                     batch_size=batch_size,
                     verbose=1,
                     epochs=nb_epoch,
                     validation_split=valrate,
                     callbacks=[lrs, mcp])

    json_string = model.to_json()
    json_string += '##########' + str(ClassNames)
    open('./keras/model.json', 'w').write(json_string)
    model.save_weights('./keras/last.hdf5')

# %%
Learning(tsnum=30, nb_epoch=50, batch_size=8, learn_schedule=0.9)
# Out:
# >> 学習サンプル数 :  (200, 16, 16, 3)
# >> 学習開始
# /opt/anaconda3/lib/python3.7/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 15/18 [========================>.....] - ETA: 0s - loss: 0.7187 - accuracy: 0.5333
# Epoch 00001: val_loss improved from inf to 0.67588, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.7059 - accuracy: 0.5714 - val_loss: 0.6759 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.6859 - accuracy: 0.5982
# Epoch 00002: val_loss improved from 0.67588 to 0.66538, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.6906 - accuracy: 0.5571 - val_loss: 0.6654 - val_accuracy: 0.5000 - lr: 9.0000e-04
# Epoch 3/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.6819 - accuracy: 0.5446
# Epoch 00003: val_loss improved from 0.66538 to 0.65052, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.6766 - accuracy: 0.5500 - val_loss: 0.6505 - val_accuracy: 0.5000 - lr: 8.1000e-04
# Epoch 4/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.6117 - accuracy: 0.6471
# Epoch 00004: val_loss improved from 0.65052 to 0.55772, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 19ms/step - loss: 0.6094 - accuracy: 0.6500 - val_loss: 0.5577 - val_accuracy: 0.9667 - lr: 7.2900e-04
# Epoch 5/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.5043 - accuracy: 0.7500
# Epoch 00005: val_loss improved from 0.55772 to 0.34967, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.4909 - accuracy: 0.7643 - val_loss: 0.3497 - val_accuracy: 0.9000 - lr: 6.5610e-04
# Epoch 6/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.3299 - accuracy: 0.8824
# Epoch 00006: val_loss improved from 0.34967 to 0.19413, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 1s 29ms/step - loss: 0.3344 - accuracy: 0.8786 - val_loss: 0.1941 - val_accuracy: 0.9167 - lr: 5.9049e-04
# Epoch 7/50
# 18/18 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9571
# Epoch 00007: val_loss improved from 0.19413 to 0.04202, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 19ms/step - loss: 0.1998 - accuracy: 0.9571 - val_loss: 0.0420 - val_accuracy: 1.0000 - lr: 5.3144e-04
# Epoch 8/50
# 18/18 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9643
# Epoch 00008: val_loss improved from 0.04202 to 0.01488, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 19ms/step - loss: 0.1012 - accuracy: 0.9643 - val_loss: 0.0149 - val_accuracy: 1.0000 - lr: 4.7830e-04
# Epoch 9/50
# 15/18 [========================>.....] - ETA: 0s - loss: 0.0455 - accuracy: 1.0000
# Epoch 00009: val_loss improved from 0.01488 to 0.00583, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 1.0000 - lr: 4.3047e-04
# Epoch 10/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0625 - accuracy: 0.9779
# Epoch 00010: val_loss did not improve from 0.00583
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0615 - accuracy: 0.9786 - val_loss: 0.0261 - val_accuracy: 1.0000 - lr: 3.8742e-04
# Epoch 11/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.0406 - accuracy: 0.9911
# Epoch 00011: val_loss improved from 0.00583 to 0.00299, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0600 - accuracy: 0.9786 - val_loss: 0.0030 - val_accuracy: 1.0000 - lr: 3.4868e-04
# Epoch 12/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.0207 - accuracy: 1.0000
# Epoch 00012: val_loss improved from 0.00299 to 0.00229, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.0023 - val_accuracy: 1.0000 - lr: 3.1381e-04
# Epoch 13/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.0112 - accuracy: 1.0000
# Epoch 00013: val_loss improved from 0.00229 to 0.00156, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0218 - accuracy: 0.9929 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 2.8243e-04
# Epoch 14/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0064 - accuracy: 1.0000
# Epoch 00014: val_loss improved from 0.00156 to 0.00154, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 27ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 1.0000 - lr: 2.5419e-04
# Epoch 15/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000
# Epoch 00015: val_loss improved from 0.00154 to 0.00087, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 8.6937e-04 - val_accuracy: 1.0000 - lr: 2.2877e-04
# Epoch 16/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00016: val_loss improved from 0.00087 to 0.00049, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 4.8922e-04 - val_accuracy: 1.0000 - lr: 2.0589e-04
# Epoch 17/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.0351 - accuracy: 0.9911
# Epoch 00017: val_loss did not improve from 0.00049
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0372 - accuracy: 0.9857 - val_loss: 0.0016 - val_accuracy: 1.0000 - lr: 1.8530e-04
# Epoch 18/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 00018: val_loss improved from 0.00049 to 0.00045, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 4.5351e-04 - val_accuracy: 1.0000 - lr: 1.6677e-04
# Epoch 19/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 00019: val_loss improved from 0.00045 to 0.00038, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 3.7845e-04 - val_accuracy: 1.0000 - lr: 1.5009e-04
# Epoch 20/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 00020: val_loss improved from 0.00038 to 0.00033, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.3157e-04 - val_accuracy: 1.0000 - lr: 1.3509e-04
# Epoch 21/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00021: val_loss improved from 0.00033 to 0.00030, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.0048e-04 - val_accuracy: 1.0000 - lr: 1.2158e-04
# Epoch 22/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00022: val_loss improved from 0.00030 to 0.00029, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.8963e-04 - val_accuracy: 1.0000 - lr: 1.0942e-04
# Epoch 23/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00023: val_loss improved from 0.00029 to 0.00024, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.4235e-04 - val_accuracy: 1.0000 - lr: 9.8477e-05
# Epoch 24/50
# 15/18 [========================>.....] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00024: val_loss improved from 0.00024 to 0.00020, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 2.0390e-04 - val_accuracy: 1.0000 - lr: 8.8629e-05
# Epoch 25/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00025: val_loss improved from 0.00020 to 0.00020, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.0177e-04 - val_accuracy: 1.0000 - lr: 7.9766e-05
# Epoch 26/50
# 15/18 [========================>.....] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00026: val_loss did not improve from 0.00020
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.2289e-04 - val_accuracy: 1.0000 - lr: 7.1790e-05
# Epoch 27/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00027: val_loss did not improve from 0.00020
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.0669e-04 - val_accuracy: 1.0000 - lr: 6.4611e-05
# Epoch 28/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00028: val_loss improved from 0.00020 to 0.00017, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 1.7459e-04 - val_accuracy: 1.0000 - lr: 5.8150e-05
# Epoch 29/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00029: val_loss improved from 0.00017 to 0.00016, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.5506e-04 - val_accuracy: 1.0000 - lr: 5.2335e-05
# Epoch 30/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00030: val_loss improved from 0.00016 to 0.00012, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.2493e-04 - val_accuracy: 1.0000 - lr: 4.7101e-05
# Epoch 31/50
# 16/18 [=========================>....] - ETA: 0s - loss: 8.1851e-04 - accuracy: 1.0000
# Epoch 00031: val_loss improved from 0.00012 to 0.00012, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1983e-04 - val_accuracy: 1.0000 - lr: 4.2391e-05
# Epoch 32/50
# 15/18 [========================>.....] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00032: val_loss improved from 0.00012 to 0.00012, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.1701e-04 - val_accuracy: 1.0000 - lr: 3.8152e-05
# Epoch 33/50
# 15/18 [========================>.....] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00033: val_loss improved from 0.00012 to 0.00012, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1549e-04 - val_accuracy: 1.0000 - lr: 3.4337e-05
# Epoch 34/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00034: val_loss improved from 0.00012 to 0.00011, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.1320e-04 - val_accuracy: 1.0000 - lr: 3.0903e-05
# Epoch 35/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00035: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.1811e-04 - val_accuracy: 1.0000 - lr: 2.7813e-05
# Epoch 36/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00036: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2467e-04 - val_accuracy: 1.0000 - lr: 2.5032e-05
# Epoch 37/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00037: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.2142e-04 - val_accuracy: 1.0000 - lr: 2.2528e-05
# Epoch 38/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00038: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.2031e-04 - val_accuracy: 1.0000 - lr: 2.0276e-05
# Epoch 39/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00039: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.1665e-04 - val_accuracy: 1.0000 - lr: 1.8248e-05
# Epoch 40/50
# 14/18 [======================>.......] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00040: val_loss improved from 0.00011 to 0.00011, saving model to ./keras/best.hdf5
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.1225e-04 - val_accuracy: 1.0000 - lr: 1.6423e-05
# Epoch 41/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 00041: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.2139e-04 - val_accuracy: 1.0000 - lr: 1.4781e-05
# Epoch 42/50
# 15/18 [========================>.....] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000    : 0s - loss: 5.7427e-04 - accuracy
# Epoch 00042: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.2235e-04 - val_accuracy: 1.0000 - lr: 1.3303e-05
# Epoch 43/50
# 15/18 [========================>.....] - ETA: 0s - loss: 9.0103e-04 - accuracy: 1.0000
# Epoch 00043: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 20ms/step - loss: 8.4652e-04 - accuracy: 1.0000 - val_loss: 1.2028e-04 - val_accuracy: 1.0000 - lr: 1.1973e-05
# Epoch 44/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00044: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.1739e-04 - val_accuracy: 1.0000 - lr: 1.0775e-05
# Epoch 45/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00045: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.1816e-04 - val_accuracy: 1.0000 - lr: 9.6977e-06
# Epoch 46/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00046: val_loss did not improve from 0.00011
# 18/18 [==============================] - 1s 32ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1824e-04 - val_accuracy: 1.0000 - lr: 8.7280e-06
# Epoch 47/50
# 18/18 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00047: val_loss did not improve from 0.00011
# 18/18 [==============================] - 1s 31ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1976e-04 - val_accuracy: 1.0000 - lr: 7.8552e-06
# Epoch 48/50
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 00048: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 22ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1890e-04 - val_accuracy: 1.0000 - lr: 7.0697e-06
# Epoch 49/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00049: val_loss did not improve from 0.00011
# 18/18 [==============================] - 0s 28ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.1941e-04 - val_accuracy: 1.0000 - lr: 6.3627e-06
# Epoch 50/50
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00050: val_loss did not improve from 0.00011
# 18/18 [==============================] - 1s 28ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.2048e-04 - val_accuracy: 1.0000 - lr: 5.7264e-06

# %%
def TestProcess(imgname):
    modelname_text = open("./keras/model.json").read()
    json_strings = modelname_text.split('##########')
    textlist = json_strings[1].replace("[", "").replace("]", "").replace("\'", "").split()
    model = model_from_json(json_strings[0])
    model.load_weights("./keras/last.hdf5")  # best.hdf5 で損失最小のパラメータを使用
    img = load_img(imgname, target_size=(hw["height"], hw["width"]))    
    TEST = img_to_array(img) / 255

    pred = model.predict(np.array([TEST]), batch_size=1, verbose=0)
    print(">> 計算結果↓\n" + str(pred))
    print(">> この画像は「" + textlist[np.argmax(pred)].replace(",", "") + "」です。")
    print(textlist[np.argmax(pred)] == "good_hair")

# %%
TestProcess("./dataset/good_hair/0.jpg")
# Out:
# >> 計算結果↓
# [[9.219777e-06 9.999908e-01]]
# >> この画像は「good_hair」です。
# True

# %%
textlist[np.argmax(pred)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c994cfa6cc6a> in <module>
# ----> 1 textlist[np.argmax(pred)]
#
# NameError: name 'textlist' is not defined
